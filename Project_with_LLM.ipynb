# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyankamunrathi/Project-with-LLM/blob/main/Project_with_LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Use case: “Policy & Claims Copilot” (Customer support + Claims pre-check)
# !pip install PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 4.5 MB/s eta 0:00:00
# ...

# %%
import PyPDF2

# %%
# Open PDF file
file = open('SBI_Health_Insurance_Policy.pdf', 'rb')
reader = PyPDF2.PdfReader(file)

# %%
# Read text from PDF
text = ""
for i in range(len(reader.pages)):
    page = reader.pages[i]
    text += page.extract_text()
print("PDF loaded")
# Out:
# PDF loaded

# %%
# Trying to create question function (incomplete)
def ask_question(question):
    question = question.lower()

    # Not sure how to search properly in full text
    if question in text:
        print("Found something in document")
    else:
        print("Not able to find exact answer")

# %%
# Hi Rakhi ji I am stuck here,I am confused how to proceed searching part and retrieve the data from pdf.
# I tried keyword-based answering and also tried searching the text,
# but I’m not sure how to extract exact relevant answers from the document.

# %%
def ask_question(question):
    question = question.lower()

    # Trying keyword matching
    if "cover" in question:
        print("Answer: It covers hospital expenses and medicines")

    elif "exclusion" in question:
        print("Answer: Some diseases are not covered")

    elif "claim" in question:
        print("Answer: Need to submit documents to claim")

    else:
        if question in text:
            print("Some content found but not sure how to extract exact answer")
        else:
            print("Not able to answer properly")

# Testing questions
ask_question("What is covered?")
ask_question("What are exclusions?")
ask_question("How to claim?")
# Out:
# Answer: It covers hospital expenses and medicines
# Answer: Some diseases are not covered
# Answer: Need to submit documents to claim

# %%
# I tried splitting the document into chunks and searching within them
# but I’m not sure how to retrieve the most relevant chunk and generate proper answers.

# %%
# Trying to split text into chunks (not sure if correct)

chunk_size = 500
chunks = []

for i in range(0, len(text), chunk_size):
    part = text[i:i+chunk_size]
    chunks.append(part)
print("Total chunks created:", len(chunks))

# Trying to search in chunks
def ask_question(question):
    question = question.lower()

    found = False

    for chunk in chunks:
        if question in chunk.lower():
            print("Found something in chunk:")
            print(chunk[:200])   # printing small part
            found = True
            break

    if not found:
        print("Not able to find answer properly")

# Testing
ask_question("coverage")
ask_question("claim process")
# Out:
# Total chunks created: 191
# Found something in chunk:
# nsured Person ’s legal Spouse, Insured Person ’s legal &
# dependent children and dependent parents
#
# “Grace Period ” means the specified period of 15 days  immediatel y following the premium due date
# Not able to find answer properly
